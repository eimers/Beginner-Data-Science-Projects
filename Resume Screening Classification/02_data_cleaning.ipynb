# %% [markdown]
# # Resume Screening / Classification — 02 Text Cleaning
#
# Produce a `clean_text` column: lowercase, strip URLs/HTML/punctuation/digits, remove stopwords and very short tokens. This is the text the TF-IDF vectorizer consumes in notebook 03.

# %%
import pandas as pd
import utils
df=utils.load_data()
print('rows:',len(df))
# Out:
# rows: 962

# %% [markdown]
# ## 1. Apply cleaning

# %%
df['clean_text']=df['text'].astype(str).map(utils.clean_text)
df=df[df['clean_text'].str.strip()!='']
print('after cleaning:',len(df),'rows')
# Out:
# after cleaning: 962 rows

# %% [markdown]
# ## 2. Before / after example

# %%
ex=df.iloc[0]
print('RAW  :',str(ex['text'])[:200].replace(chr(10),' '))
print('\nCLEAN:',ex['clean_text'][:200])
# Out:
# RAW  : Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision T
#
# CLEAN: skills programming languages python pandas numpy scipy scikit learn matplotlib sql java javascript jquery machine learning regression svm na bayes knn random forest decision trees boosting techniques

# %% [markdown]
# ## 3. Save cleaned data

# %%
df[['clean_text','label']].to_csv('data/resumes_cleaned.csv',index=False)
print('saved data/resumes_cleaned.csv',df.shape)
# Out:
# saved data/resumes_cleaned.csv (962, 3)
