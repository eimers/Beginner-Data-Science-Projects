# %% [markdown]
# # Cryptocurrency Price Trend Analysis — 02 Feature Engineering & Split
#
# Time series can't be shuffled. We build **lag features** (past values), **rolling** mean/std, and **calendar** features, then split **chronologically** (train on the past, test on the most recent slice).

# %%
import pandas as pd
import utils
df=utils.load_data()
print('raw rows:',len(df))
# Out:
# raw rows: 365

# %% [markdown]
# ## 1. Build features (lags + rolling + calendar)

# %%
feat=utils.build_features(df)
print('featured rows:',len(feat),'| features:',len(utils.feature_columns(feat)))
print('feature columns:',utils.feature_columns(feat))
feat.head()
# Out:
# featured rows: 351 | features: 13
# feature columns: ['month', 'day', 'dayofweek', 'dayofyear', 'is_weekend', 'lag_1', 'lag_2', 'lag_3', 'lag_7', 'rollmean_7', 'rollstd_7', 'rollmean_14', 'rollstd_14']
#         date              y  month  day  dayofweek  dayofyear  is_weekend  \
# 0 2025-07-15  119833.674467      7   15          1        196           0
# 1 2025-07-16  117678.194934      7   16          2        197           0
# 2 2025-07-17  118748.162737      7   17          3        198           0
# 3 2025-07-18  119445.365204      7   18          4        199           0
# 4 2025-07-19  117988.946645      7   19          5        200           1
#
#            lag_1          lag_2          lag_3          lag_7     rollmean_7  \
# 0  119117.556663  117418.957450  117571.025100  108300.716758  114081.232670
# 1  119833.674467  119117.556663  117418.957450  108953.191877  115728.798057
# 2  117678.194934  119833.674467  119117.556663  111327.530542  116975.227065
# 3  118748.162737  117678.194934  119833.674467  115879.650301  118035.317379
# 4  119445.365204  118748.162737  117678.194934  117571.025100  118544.705222
#
#      rollstd_7    rollmean_14   rollstd_14
# 0  4457.427607  111086.788198  4436.790060
# 1  4080.173316  111993.993581  4845.759968
# 2  2795.922564  112855.764666  4694.179221
# 3  1309.158920  113564.601702  4786.950633
# 4   983.902515  114267.684585  4882.117176

# %% [markdown]
# ## 2. Chronological train/test split

# %%
train,test=utils.chronological_split(feat,test_frac=0.2)
print('train:',len(train),'(',train.date.min().date(),'->',train.date.max().date(),')')
print('test :',len(test),'(',test.date.min().date(),'->',test.date.max().date(),')')
# Out:
# train: 280 ( 2025-07-15 -> 2026-04-20 )
# test : 71 ( 2026-04-21 -> 2026-06-30 )

# %% [markdown]
# ## 3. Save featured data

# %%
feat.to_csv('data/featured.csv',index=False)
print('saved data/featured.csv',feat.shape)
# Out:
# saved data/featured.csv (351, 15)
