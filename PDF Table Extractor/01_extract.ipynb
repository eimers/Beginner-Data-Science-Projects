# %% [markdown]
# # PDF Table Extractor + Analyzer — 01 Extraction
#
# Financial reports lock their numbers inside PDF tables. This project extracts those tables with **pdfplumber** and turns them into DataFrames. The sample `data/financial_report.pdf` contains two tables.

# %%
import pandas as pd
import utils
tables=utils.extract_tables()
print('tables found:',len(tables))
for i,t in enumerate(tables): print(f'  table {i}: {len(t)} rows x {len(t[0])} cols | header {t[0]}')
# Out:
# tables found: 2
#   table 0: 5 rows x 5 cols | header ['Region', 'Q1', 'Q2', 'Q3', 'Q4']
#   table 1: 6 rows x 4 cols | header ['Category', '2023', '2024', 'Change %']

# %% [markdown]
# ## 1. Table 1 — Quarterly revenue by region

# %%
rev=utils.to_dataframe(tables[0],numeric_cols=['Q1','Q2','Q3','Q4'])
rev
# Out:
#           Region     Q1     Q2     Q3     Q4
# 0  North America  120.5  135.2  142.8  158.3
# 1         Europe   88.1   92.4   95.6  101.2
# 2   Asia Pacific   64.3   71.8   79.2   88.5
# 3  Latin America   22.4   24.1   26.8   29.3

# %% [markdown]
# ## 2. Table 2 — Operating expenses by category

# %%
exp=utils.to_dataframe(tables[1],numeric_cols=['2023','2024','Change %'])
exp
# Out:
#      Category   2023   2024  Change %
# 0    Salaries  210.0  238.5      13.6
# 1   Marketing   45.2   52.8      16.8
# 2         R&D   78.9   95.4      20.9
# 3  Operations   62.1   64.3       3.5
# 4       Other   18.4   19.9       8.2

# %% [markdown]
# ## 3. Summary
#
# - **Both tables extract cleanly** into structured DataFrames — headers, rows, and numeric cells all recovered from the PDF.
# - Notebook 02 analyses the extracted numbers (totals, growth) as if they came from any tabular source.
