# %% [markdown]
# # Amazon Review Sentiment Analysis — 02 Text Cleaning
#
# Produce a `clean_text` column: lowercase, strip URLs/HTML/punctuation/digits, remove stopwords and very short tokens. This is the text the TF-IDF vectorizer consumes in notebook 03.

# %%
import pandas as pd
import utils
df=utils.load_data()
print('rows:',len(df))
# Out:
# rows: 30000

# %% [markdown]
# ## 1. Apply cleaning

# %%
df['clean_text']=df['text'].astype(str).map(utils.clean_text)
df=df[df['clean_text'].str.strip()!='']
print('after cleaning:',len(df),'rows')
# Out:
# after cleaning: 30000 rows

# %% [markdown]
# ## 2. Before / after example

# %%
ex=df.iloc[0]
print('RAW  :',str(ex['text'])[:200].replace(chr(10),' '))
print('\nCLEAN:',ex['clean_text'][:200])
# Out:
# RAW  : It all sounds the same, but.... It's all good. This album suffers from a common problem among metal albums in that almost all the songs sound very similar, but in this case it just doesn't matter beca
#
# CLEAN: sounds good album suffers common problem among metal albums almost songs sound similar case matter enjoyable haunting vocals masterful pacing instrumentals every song actually fairly inspiring listen

# %% [markdown]
# ## 3. Save cleaned data

# %%
df[['clean_text','label']].to_csv('data/reviews_cleaned.csv',index=False)
print('saved data/reviews_cleaned.csv',df.shape)
# Out:
# saved data/reviews_cleaned.csv (30000, 3)
