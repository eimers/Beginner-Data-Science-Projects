# %% [markdown]
# # Toxic Comment Classification — 02 Text Cleaning
#
# Produce a `clean_text` column: lowercase, strip URLs/HTML/punctuation/digits, remove stopwords and very short tokens. This is the text the TF-IDF vectorizer consumes in notebook 03.

# %%
import pandas as pd
import utils
df=utils.load_data()
print('rows:',len(df))
# Out:
# rows: 40000

# %% [markdown]
# ## 1. Apply cleaning

# %%
df['clean_text']=df['text'].astype(str).map(utils.clean_text)
df=df[df['clean_text'].str.strip()!='']
print('after cleaning:',len(df),'rows')
# Out:
# after cleaning: 39978 rows

# %% [markdown]
# ## 2. Before / after example

# %%
ex=df.iloc[0]
print('RAW  :',str(ex['text'])[:200].replace(chr(10),' '))
print('\nCLEAN:',ex['clean_text'][:200])
# Out:
# RAW  : it's unfortunate that your mother didn't quif you out the day she was raped by the pig you call a father you sodomite bible thumping nazi. -steve  It is unlikely this individual speaks for (or belongs
#
# CLEAN: unfortunate mother quif day raped pig call father sodomite bible thumping nazi steve unlikely individual speaks belongs left nope tell lack education hate speach right winger go dubya yuk yuk yuk

# %% [markdown]
# ## 3. Save cleaned data

# %%
df[['clean_text','label']].to_csv('data/comments_cleaned.csv',index=False)
print('saved data/comments_cleaned.csv',df.shape)
# Out:
# saved data/comments_cleaned.csv (39978, 3)
