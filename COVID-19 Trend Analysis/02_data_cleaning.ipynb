# %% [markdown]
# # COVID-19 Trend Analysis — 02 Feature Engineering & Split
#
# Time series can't be shuffled. We build **lag features** (past values), **rolling** mean/std, and **calendar** features, then split **chronologically** (train on the past, test on the most recent slice).

# %%
import pandas as pd
import utils
df=utils.load_data()
print('raw rows:',len(df))
# Out:
# raw rows: 1143

# %% [markdown]
# ## 1. Build features (lags + rolling + calendar)

# %%
feat=utils.build_features(df)
print('featured rows:',len(feat),'| features:',len(utils.feature_columns(feat)))
print('feature columns:',utils.feature_columns(feat))
feat.head()
# Out:
# featured rows: 1129 | features: 14
# feature columns: ['month', 'day', 'dayofweek', 'dayofyear', 'is_weekend', 'lag_1', 'lag_2', 'lag_3', 'lag_7', 'lag_14', 'rollmean_7', 'rollstd_7', 'rollmean_14', 'rollstd_14']
#         date     y  month  day  dayofweek  dayofyear  is_weekend   lag_1  \
# 0 2020-02-05  3745      2    5          2         36           0  4012.0
# 1 2020-02-06  3162      2    6          3         37           0  3745.0
# 2 2020-02-07  3594      2    7          4         38           0  3162.0
# 3 2020-02-08  2731      2    8          5         39           1  3594.0
# 4 2020-02-09  3031      2    9          6         40           1  2731.0
#
#     lag_2   lag_3   lag_7  lag_14   rollmean_7    rollstd_7  rollmean_14  \
# 0  3100.0  4749.0   589.0     0.0  2617.000000  1429.119076  1667.285714
# 1  4012.0  3100.0  2068.0   100.0  3067.857143  1154.049599  1934.785714
# 2  3745.0  4012.0  1690.0   287.0  3224.142857  1066.861039  2153.500000
# 3  3162.0  3745.0  2111.0   493.0  3496.142857   826.081802  2389.714286
# 4  3594.0  3162.0  4749.0   683.0  3584.714286   671.611920  2549.571429
#
#     rollstd_14
# 0  1513.058971
# 1  1526.604688
# 2  1461.471795
# 3  1402.655582
# 4  1293.116255

# %% [markdown]
# ## 2. Chronological train/test split

# %%
train,test=utils.chronological_split(feat,test_frac=0.2)
print('train:',len(train),'(',train.date.min().date(),'->',train.date.max().date(),')')
print('test :',len(test),'(',test.date.min().date(),'->',test.date.max().date(),')')
# Out:
# train: 903 ( 2020-02-05 -> 2022-07-26 )
# test : 226 ( 2022-07-27 -> 2023-03-09 )

# %% [markdown]
# ## 3. Save featured data

# %%
feat.to_csv('data/featured.csv',index=False)
print('saved data/featured.csv',feat.shape)
# Out:
# saved data/featured.csv (1129, 16)
