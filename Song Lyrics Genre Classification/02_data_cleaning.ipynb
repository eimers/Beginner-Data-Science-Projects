# %% [markdown]
# # Song Lyrics Genre Classification — 02 Text Cleaning
#
# Produce a `clean_text` column: lowercase, strip URLs/HTML/punctuation/digits, remove stopwords and very short tokens. This is the text the TF-IDF vectorizer consumes in notebook 03.

# %%
import pandas as pd
import utils
df=utils.load_data()
print('rows:',len(df))
# Out:
# rows: 6000

# %% [markdown]
# ## 1. Apply cleaning

# %%
df['clean_text']=df['text'].astype(str).map(utils.clean_text)
df=df[df['clean_text'].str.strip()!='']
print('after cleaning:',len(df),'rows')
# Out:
# after cleaning: 6000 rows

# %% [markdown]
# ## 2. Before / after example

# %%
ex=df.iloc[0]
print('RAW  :',str(ex['text'])[:200].replace(chr(10),' '))
print('\nCLEAN:',ex['clean_text'][:200])
# Out:
# RAW  : [Intro] Keepin' it jiggy Bogle, John, Sadiki! 2004, it's gonna be jiggy!  [Hook] What a Weddi, Weddi, Weddi, Weddi (March out! March out!) Weddi, Weddi, Weddi, Weddi Weddi, Weddi, Weddi, Weddi (March
#
# CLEAN: intro keepin jiggy bogle john sadiki gonna jiggy hook weddi weddi weddi weddi march march weddi weddi weddi weddi weddi weddi weddi weddi march march weddi weddi weddi weddi weddi weddi weddi march ma

# %% [markdown]
# ## 3. Save cleaned data

# %%
df[['clean_text','label']].to_csv('data/lyrics_cleaned.csv',index=False)
print('saved data/lyrics_cleaned.csv',df.shape)
# Out:
# saved data/lyrics_cleaned.csv (6000, 3)
