# %% [markdown]
# # Retail Sales Forecasting — 02 Feature Engineering & Split
#
# Time series can't be shuffled. We build **lag features** (past values), **rolling** mean/std, and **calendar** features, then split **chronologically** (train on the past, test on the most recent slice).

# %%
import pandas as pd
import utils
df=utils.load_data()
print('raw rows:',len(df))
# Out:
# raw rows: 305

# %% [markdown]
# ## 1. Build features (lags + rolling + calendar)

# %%
feat=utils.build_features(df)
print('featured rows:',len(feat),'| features:',len(utils.feature_columns(feat)))
print('feature columns:',utils.feature_columns(feat))
feat.head()
# Out:
# featured rows: 291 | features: 13
# feature columns: ['month', 'day', 'dayofweek', 'dayofyear', 'is_weekend', 'lag_1', 'lag_2', 'lag_3', 'lag_7', 'rollmean_7', 'rollstd_7', 'rollmean_14', 'rollstd_14']
#         date         y  month  day  dayofweek  dayofyear  is_weekend  \
# 0 2010-12-17  45418.33     12   17          4        351           0
# 1 2010-12-19   7534.91     12   19          6        353           1
# 2 2010-12-20  26789.13     12   20          0        354           0
# 3 2010-12-21  47304.09     12   21          1        355           0
# 4 2010-12-22   6199.97     12   22          2        356           0
#
#       lag_1     lag_2     lag_3     lag_7    rollmean_7     rollstd_7  \
# 0  49352.90  30444.62  45254.73  53586.18  41879.590000  14446.321225
# 1  45418.33  49352.90  30444.62  59182.92  40712.754286  13651.160353
# 2   7534.91  45418.33  49352.90  17329.07  33334.467143  15793.846669
# 3  26789.13   7534.91  45418.33  38006.71  34685.904286  14551.961951
# 4  47304.09  26789.13   7534.91  45254.73  36014.101429  15310.125660
#
#     rollmean_14    rollstd_14
# 0  48458.828571  18839.242933
# 1  47491.510000  18604.746149
# 2  44619.119286  21448.920780
# 3  43179.506429  21951.380958
# 4  44288.730714  21721.920195

# %% [markdown]
# ## 2. Chronological train/test split

# %%
train,test=utils.chronological_split(feat,test_frac=0.2)
print('train:',len(train),'(',train.date.min().date(),'->',train.date.max().date(),')')
print('test :',len(test),'(',test.date.min().date(),'->',test.date.max().date(),')')
# Out:
# train: 232 ( 2010-12-17 -> 2011-10-02 )
# test : 59 ( 2011-10-03 -> 2011-12-09 )

# %% [markdown]
# ## 3. Save featured data

# %%
feat.to_csv('data/featured.csv',index=False)
print('saved data/featured.csv',feat.shape)
# Out:
# saved data/featured.csv (291, 15)
