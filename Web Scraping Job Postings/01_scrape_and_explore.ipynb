# %% [markdown]
# # Web Scraping + Analysis (Job Postings) — 01 Scrape & Explore
#
# We scrape live remote-job postings from the **RemoteOK public API**, then analyse what skills and roles are in demand. `data/jobs.csv` is a saved snapshot so the notebook is reproducible; `utils.fetch_jobs()` re-scrapes fresh data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import utils
df=utils.load_jobs()
print('postings scraped:',len(df))
df[['position','company','location','tags']].head()
# Out:
# postings scraped: 100
#                                             position  \
# 0            Paid Media Specialist Meta & Google Ads
# 1                                          Custodian
# 2                                          Lifeguard
# 3  Dutch Speaking Customer Service Agent For Impe...
# 4                                       Multi Trader
#
#                                  company       location  \
# 0                         Noventra Group         Remote
# 1  Hospitality Newfoundland and Labrador  St Johnâs,
# 2                                  Accor       Bardez,
# 3                    Mercier Consultancy         Remote
# 4                           B&amp;R HOME       London,
#
#                                                 tags
# 0  Marketing,Paid Media,Meta Ads,Facebook Ads,Goo...
# 1                  customer support,c,exec,full time
# 2                    education,customer support,exec
# 3  consulting,work from home,customer support,c,m...
# ...

# %% [markdown]
# ## 1. How the scrape works
#
# ```python
# # utils.fetch_jobs() hits https://remoteok.com/api and parses the JSON
# # into position / company / location / tags / date. We saved one pull to CSV.
# ```

# %%
print('columns:',list(df.columns))
print('unique companies:',df.company.nunique())
print('date range:',df.date.min(),'->',df.date.max())
# Out:
# columns: ['position', 'company', 'location', 'tags', 'salary_min', 'salary_max', 'date']
# unique companies: 87
# date range: 2026-07-02T09:57:12+00:00 -> 2026-07-07T05:08:56+00:00

# %% [markdown]
# ## 2. Summary
#
# - ~100 live remote postings pulled in one API call.
# - Each carries a role title, company, location, and a set of skill/category **tags** — the richest field for analysis (notebook 02).
# - Note: RemoteOK's API does not reliably expose salary, so we focus on roles, skills, and companies.
