# %% [markdown]
# # Uber Ride Demand Forecasting — 02 Feature Engineering & Split
#
# Time series can't be shuffled. We build **lag features** (past values), **rolling** mean/std, and **calendar** features, then split **chronologically** (train on the past, test on the most recent slice).

# %%
import pandas as pd
import utils
df=utils.load_data()
print('raw rows:',len(df))
# Out:
# raw rows: 183

# %% [markdown]
# ## 1. Build features (lags + rolling + calendar)

# %%
feat=utils.build_features(df)
print('featured rows:',len(feat),'| features:',len(utils.feature_columns(feat)))
print('feature columns:',utils.feature_columns(feat))
feat.head()
# Out:
# featured rows: 169 | features: 12
# feature columns: ['month', 'day', 'dayofweek', 'dayofyear', 'is_weekend', 'lag_1', 'lag_2', 'lag_3', 'lag_7', 'lag_14', 'rollmean_7', 'rollstd_7']
#         date      y  month  day  dayofweek  dayofyear  is_weekend    lag_1  \
# 0 2014-04-15  20641      4   15          1        105           0  12674.0
# 1 2014-04-16  17717      4   16          2        106           0  20641.0
# 2 2014-04-17  20973      4   17          3        107           0  17717.0
# 3 2014-04-18  18074      4   18          4        108           0  20973.0
# 4 2014-04-19  14602      4   19          5        109           1  18074.0
#
#      lag_2    lag_3    lag_7   lag_14    rollmean_7    rollstd_7
# 0  12112.0  18170.0  16188.0  14546.0  16635.428571  3283.123709
# 1  12674.0  12112.0  16843.0  17474.0  17271.571429  3598.265177
# 2  20641.0  12674.0  20041.0  20701.0  17396.428571  3596.078459
# 3  17717.0  20641.0  20420.0  26714.0  17529.571429  3725.244907
# 4  20973.0  17717.0  18170.0  19521.0  17194.428571  3521.843213

# %% [markdown]
# ## 2. Chronological train/test split

# %%
train,test=utils.chronological_split(feat,test_frac=0.2)
print('train:',len(train),'(',train.date.min().date(),'->',train.date.max().date(),')')
print('test :',len(test),'(',test.date.min().date(),'->',test.date.max().date(),')')
# Out:
# train: 135 ( 2014-04-15 -> 2014-08-27 )
# test : 34 ( 2014-08-28 -> 2014-09-30 )

# %% [markdown]
# ## 3. Save featured data

# %%
feat.to_csv('data/featured.csv',index=False)
print('saved data/featured.csv',feat.shape)
# Out:
# saved data/featured.csv (169, 14)
